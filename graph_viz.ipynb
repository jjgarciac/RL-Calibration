# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ID_1 = 1620155360
ID_2 = 1620158999
env = "Cartpole"
#k1 = np.maximum.accumulate(np.load('cheetah_k1_ph20_ps10_np12_ntrain30_cFalse.npy').squeeze())
k1_c = np.maximum.accumulate(np.load(f'./experiments/{ID_1}/returns.npy').squeeze())
k3 = np.maximum.accumulate(np.load(f'./experiments/{ID_2}/returns.npy').squeeze())
print(k1_c)
#k3_c = np.maximum.accumulate(np.load('cheetah_k3_ph20_ps10_np12_ntrain30_cTrue.npy').squeeze())
#k1_c = np.load(f'./experiments/{ID_1}/returns.npy').squeeze()
#k3 = np.load(f'./experiments/{ID_2}/returns.npy').squeeze()
# Out:
# [176. 176. 176. 176. 176.]

# %%
# plt.style.use('dark_background')
fig, ax = plt.subplots()
ax.set_title(f'{env}')
ax.set_ylabel('Maximum reward obtained in a horizon up to (t)')
ax.set_xlabel('Number of iterations (t)')
#ax.plot(k1, label='PE')
ax.plot(k1_c, label='calibrated PETS')
ax.plot(k3, label='PETS++')
#ax.plot(k3_c, label='calibrated Ours')
ax.legend(loc='lower right')
plt.show()

# %%
k1 = np.load('cheetah_k1_ph20_ps10_np12_ntrain30_cFalse.npy').squeeze()
k1_c = np.load('cheetah_k1_ph20_ps10_np12_ntrain30_cTrue.npy').squeeze()
k3 = np.load('cheetah_k3_ph20_ps10_np12_ntrain30_cFalse.npy').squeeze()
k3_c = np.load('cheetah_k3_ph20_ps10_np12_ntrain30_cTrue.npy').squeeze()

# %%
plt.style.use('dark_background')
fig, ax = plt.subplots()
ax.set_title('Half-Cheetah')
ax.set_ylabel('Maximum reward obtained in a horizon up to (t)')
ax.set_xlabel('Number of iterations (t)')
ax.plot(k1, label='PE')
ax.plot(k1_c, label='calibrated PE')
ax.plot(k3, label='Ours')
ax.plot(k3_c, label='calibrated Ours')
ax.legend(loc='lower right')
plt.show()
